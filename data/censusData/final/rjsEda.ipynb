# %% [markdown]
# Libraries and options

# %%
import numpy as np, pandas as pd
import sys, os, re, zipfile, shutil, pickle, matplotlib.pyplot as plt, seaborn as sns, bz2,time
import statsmodels
import scipy.stats as stats
pd.options.display.max_columns = 500
pd.options.display.max_rows = 500
pd.options.display.max_colwidth = 50

# %%
def importPbz2( file ):
    data = bz2.BZ2File(file,'rb')
    return pd.read_pickle(data)

# %%
newDF = importPbz2('covidPollutionCensus.pbz2')
# newDF = importPbz2('covidCensus.pbz2')

# %%
newDF['fips'] = newDF['fips'].astype('str').str.zfill(5)
newDF['State Code'] = newDF['State Code'].astype('str').str.zfill(5)
newDF['County Code'] = newDF['County Code'].astype('str').str.zfill(5)
newDF['dates'] = pd.to_datetime(newDF['dates'])

# %% [markdown]
# And explore...

# %%
newDF[['totalMoved','movedWithinState','movedWithoutState','movedFromAbroad','publicTrans','totalTrans','householdsTotal','houseWith65',
      'house2+with65','houseFamily65','houseNonfam65','houseNo65','house2+No65','houseFamilyNo65','houseNonfamNo65',
      'householdStructuresTotal','householdIncomeMedian','gini','hoursWorkedMean','unitsInStructure','healthInsTotal',
      'healthInsNativeWith','healthInsForeignNatWith','healthInsForeignNoncitWith','healthInsForeignNatNo',
      'healthInsForeignNoncitNo','healthInsNativeNo']]  = \
newDF[['totalMoved','movedWithinState','movedWithoutState','movedFromAbroad','publicTrans','totalTrans','householdsTotal','houseWith65',
      'house2+with65','houseFamily65','houseNonfam65','houseNo65','house2+No65','houseFamilyNo65','houseNonfamNo65',
      'householdStructuresTotal','householdIncomeMedian','gini','hoursWorkedMean','unitsInStructure','healthInsTotal',
      'healthInsNativeWith','healthInsForeignNatWith','healthInsForeignNoncitWith','healthInsForeignNatNo',
      'healthInsForeignNoncitNo','healthInsNativeNo']].astype('float64')

# %%
testDF = newDF.groupby([pd.Grouper(key='dates',freq='W'),'pollutant','fips']).agg('mean')

# %%
testDF = testDF.reset_index()#.set_index(['dates','fips','pollutant'])

# %%
testDF = testDF[testDF['dates'].between('2020-03-11','2021-03-11')]

# %%
testDF.sort_values(['dates','fips','pollutant'],inplace=True)

# %%
wokka=[i for i in testDF if not (i.endswith('.missing'))|(i.startswith('NYT'))]
testDF = testDF[wokka]

# %%
def rateCalc( numerators, denominator, DF  ):
    for col in numerators:
        DF[col+'Rate'] = DF[col] / DF[denominator]

# %%
ratesDF = testDF.copy()

rateCalc(['movedWithinState',
         'movedWithoutState',
         'movedFromAbroad'], 'totalMoved', ratesDF)

rateCalc(['publicTrans'], 'totalTrans', ratesDF)

rateCalc(['houseWith65', #householdsTotal
'house2+with65',
'houseFamily65',
'houseNonfam65',
'houseNo65',
'house2+No65',
'houseFamilyNo65',
'houseNonfamNo65'], 'householdsTotal', ratesDF)

# rateCalc(['healthInsNativeWith', #healthInsTotal
# 'healthInsForeignNatWith',
# 'healthInsForeignNoncitWith'], 'healthInsTotal', ratesDF)

rateCalc(['hospitalIcuBeds',
          'hospitalLicensedBeds',
          'hospitalStaffedBeds'], 'latestTotalPopulation', ratesDF)

rateCalc(['MaleAndFemale_AtLeast65_Population.data'], 'latestTotalPopulation', ratesDF)

ratesDF['healthInsRates']  = ratesDF[['healthInsNativeWith','healthInsForeignNatWith','healthInsForeignNoncitWith']].sum(axis=1) / ratesDF['healthInsTotal']
ratesDF['householdsWith65Rate'] = ratesDF[['houseWith65Rate','house2+with65Rate','houseNonfam65Rate','houseFamily65']].sum(axis=1)
ratesDF.drop(columns=['houseWith65', #householdsTotal
'house2+with65',
'houseFamily65',
'houseNonfam65',
'houseNo65',
'house2+No65',
'houseFamilyNo65',
'houseNonfamNo65'],inplace=True)

# %%
keep = ['dates','fips','AverageDailyTemperature.data','AveragePrecipitationTotal.data','AverageWindSpeed.data','BLS_UnemploymentRate.data',\
       'gini','hoursWorkedMean','unitsInStructure','Arithmetic Mean','density','pollutant','householdIncomeMedian']
wokka = [x for x in ratesDF if x.endswith('Rate')]
keep.extend(wokka)
ratesDF = ratesDF[keep]

# %%
cols = ['dates','fips','deathRate','Arithmetic Mean','householdIncomeMedian','AverageDailyTemperature.data','gini','hospitalStaffedBedsRate','publicTransRate','householdsWith65Rate','density']
rateFipsMean = ratesDF.loc[:,cols].groupby('fips').agg('mean')
rateFipsMean

rateCorrs = rateFipsMean.corr().sort_values('deathRate',ascending=False,key=abs)
rateCorrs
ratesDF['fips'].nunique()
# Out:
# 898

# %%
def covidPollutantFipsCorr(df, pollutant, cols=[], sort='Arithmetic Mean'):
    if cols:
        polDF =  df.loc[df['pollutant']==pollutant,cols+['fips']]
    else:
        polDF = df.loc[df['pollutant']==pollutant,:]
    fipsDF  = polDF.groupby(by='fips').agg('mean')
    corrDF = fipsDF.corr().sort_values(by=sort,ascending=False,key=abs)
    pVals = fipsDF.corr(method=lambda x, y: stats.pearsonr(x, y)[1]) - np.eye(len(corrDF.columns))
    return corrDF.round(2), pVals.loc[corrDF.index,:].round(3)

# %% [markdown]
# NO2

# %%
cols = ['dates','deathRate','Arithmetic Mean','householdIncomeMedian','AverageDailyTemperature.data','gini','hospitalStaffedBedsRate','publicTransRate','householdsWith65Rate','density']
no2Corr,pVals=covidPollutantFipsCorr(ratesDF, 'no2', cols)


rows = ['deathRate','publicTransRate','density']
no2Corr
# Out:
#                               deathRate  Arithmetic Mean  \
# deathRate                          1.00             0.25
# Arithmetic Mean                    0.25             1.00
# householdIncomeMedian              0.19             0.16
# AverageDailyTemperature.data       0.01             0.19
# gini                               0.07             0.35
# hospitalStaffedBedsRate            0.05             0.06
# publicTransRate                    0.23             0.43
# householdsWith65Rate               0.10             0.49
# density                            0.08             0.41
#
#                               householdIncomeMedian  \
# deathRate                                      0.19
# Arithmetic Mean                                0.16
# householdIncomeMedian                          1.00
# AverageDailyTemperature.data                  -0.03
# gini                                          -0.20
# hospitalStaffedBedsRate                       -0.32
# publicTransRate                                0.25
# householdsWith65Rate                           0.14
# density                                        0.20
#
#                               AverageDailyTemperature.data  gini  \
# deathRate                                             0.01  0.07
# Arithmetic Mean                                       0.19  0.35
# householdIncomeMedian                                -0.03 -0.20
# AverageDailyTemperature.data                          1.00  0.30
# gini                                                  0.30  1.00
# hospitalStaffedBedsRate                               0.01  0.38
# publicTransRate                                      -0.00  0.33
# householdsWith65Rate                                  0.28  0.29
# density                                               0.09  0.39
#
#                               hospitalStaffedBedsRate  publicTransRate  \
# deathRate                                        0.05             0.23
# Arithmetic Mean                                  0.06             0.43
# householdIncomeMedian                           -0.32             0.25
# AverageDailyTemperature.data                     0.01            -0.00
# gini                                             0.38             0.33
# hospitalStaffedBedsRate                          1.00             0.02
# publicTransRate                                  0.02             1.00
# householdsWith65Rate                            -0.00             0.25
# density                                          0.12             0.88
#
#                               householdsWith65Rate  density
# deathRate                                     0.10     0.08
# Arithmetic Mean                               0.49     0.41
# householdIncomeMedian                         0.14     0.20
# AverageDailyTemperature.data                  0.28     0.09
# gini                                          0.29     0.39
# hospitalStaffedBedsRate                      -0.00     0.12
# publicTransRate                               0.25     0.88
# householdsWith65Rate                          1.00     0.24
# density                                       0.24     1.00

# %%
# p values
# pVals = no2DF.corr(method=lambda x, y: stats.pearsonr(x, y)[1]) - np.eye(len(no2DF.corr().columns)) 
pVals
# Out:
#                               deathRate  Arithmetic Mean  \
# deathRate                         0.000            0.000
# Arithmetic Mean                   0.000            0.000
# householdIncomeMedian             0.002            0.011
# AverageDailyTemperature.data      0.875            0.002
# gini                              0.256            0.000
# hospitalStaffedBedsRate           0.490            0.379
# publicTransRate                   0.000            0.000
# householdsWith65Rate              0.112            0.000
# density                           0.204            0.000
#
#                               householdIncomeMedian  \
# deathRate                                     0.002
# Arithmetic Mean                               0.011
# householdIncomeMedian                         0.000
# AverageDailyTemperature.data                  0.626
# gini                                          0.001
# hospitalStaffedBedsRate                       0.000
# publicTransRate                               0.000
# householdsWith65Rate                          0.027
# density                                       0.002
#
#                               AverageDailyTemperature.data   gini  \
# deathRate                                            0.875  0.256
# Arithmetic Mean                                      0.002  0.000
# householdIncomeMedian                                0.626  0.001
# AverageDailyTemperature.data                         0.000  0.000
# gini                                                 0.000  0.000
# hospitalStaffedBedsRate                              0.896  0.000
# publicTransRate                                      0.964  0.000
# householdsWith65Rate                                 0.000  0.000
# density                                              0.152  0.000
#
#                               hospitalStaffedBedsRate  publicTransRate  \
# deathRate                                       0.490            0.000
# Arithmetic Mean                                 0.379            0.000
# householdIncomeMedian                           0.000            0.000
# AverageDailyTemperature.data                    0.896            0.964
# gini                                            0.000            0.000
# hospitalStaffedBedsRate                         0.000            0.803
# publicTransRate                                 0.803            0.000
# householdsWith65Rate                            0.996            0.000
# density                                         0.079            0.000
#
#                               householdsWith65Rate  density
# deathRate                                    0.112    0.204
# Arithmetic Mean                              0.000    0.000
# householdIncomeMedian                        0.027    0.002
# AverageDailyTemperature.data                 0.000    0.152
# gini                                         0.000    0.000
# hospitalStaffedBedsRate                      0.996    0.079
# publicTransRate                              0.000    0.000
# householdsWith65Rate                         0.000    0.000
# density                                      0.000    0.000

# %% [markdown]
# Ozone

# %%
cols = ['dates','deathRate','Arithmetic Mean','householdIncomeMedian','AverageDailyTemperature.data','gini','hospitalStaffedBedsRate','publicTransRate','householdsWith65Rate','density']
ozoneCorr,pVals=covidPollutantFipsCorr(ratesDF, 'ozone', cols)


rows = ['deathRate','publicTransRate','density']
ozoneCorr
# Out:
#                               deathRate  Arithmetic Mean  \
# Arithmetic Mean                   -0.05             1.00
# AverageDailyTemperature.data      -0.01            -0.30
# gini                               0.11            -0.20
# hospitalStaffedBedsRate            0.09            -0.18
# density                            0.11            -0.14
# publicTransRate                    0.25            -0.10
# deathRate                          1.00            -0.05
# householdsWith65Rate               0.15            -0.02
# householdIncomeMedian              0.13            -0.00
#
#                               householdIncomeMedian  \
# Arithmetic Mean                               -0.00
# AverageDailyTemperature.data                  -0.10
# gini                                          -0.24
# hospitalStaffedBedsRate                       -0.24
# density                                        0.26
# publicTransRate                                0.29
# deathRate                                      0.13
# householdsWith65Rate                           0.22
# householdIncomeMedian                          1.00
#
#                               AverageDailyTemperature.data  gini  \
# Arithmetic Mean                                      -0.30 -0.20
# AverageDailyTemperature.data                          1.00  0.24
# gini                                                  0.24  1.00
# hospitalStaffedBedsRate                               0.07  0.38
# density                                               0.06  0.29
# publicTransRate                                      -0.05  0.27
# deathRate                                            -0.01  0.11
# householdsWith65Rate                                  0.19  0.27
# householdIncomeMedian                                -0.10 -0.24
#
#                               hospitalStaffedBedsRate  publicTransRate  \
# Arithmetic Mean                                 -0.18            -0.10
# AverageDailyTemperature.data                     0.07            -0.05
# gini                                             0.38             0.27
# hospitalStaffedBedsRate                          1.00             0.04
# density                                          0.08             0.84
# publicTransRate                                  0.04             1.00
# deathRate                                        0.09             0.25
# householdsWith65Rate                             0.02             0.32
# householdIncomeMedian                           -0.24             0.29
#
#                               householdsWith65Rate  density
# Arithmetic Mean                              -0.02    -0.14
# AverageDailyTemperature.data                  0.19     0.06
# gini                                          0.27     0.29
# hospitalStaffedBedsRate                       0.02     0.08
# density                                       0.35     1.00
# publicTransRate                               0.32     0.84
# deathRate                                     0.15     0.11
# householdsWith65Rate                          1.00     0.35
# householdIncomeMedian                         0.22     0.26

# %%
# p values
# pVals = ozoneDF.corr(method=lambda x, y: stats.pearsonr(x, y)[1]) - np.eye(len(ozoneDF.corr().columns)) 
pVals
# Out:
#                               deathRate  Arithmetic Mean  \
# Arithmetic Mean                   0.139            0.000
# AverageDailyTemperature.data      0.829            0.000
# gini                              0.003            0.000
# hospitalStaffedBedsRate           0.026            0.000
# density                           0.003            0.000
# publicTransRate                   0.000            0.009
# deathRate                         0.000            0.139
# householdsWith65Rate              0.000            0.516
# householdIncomeMedian             0.000            0.973
#
#                               householdIncomeMedian  \
# Arithmetic Mean                               0.973
# AverageDailyTemperature.data                  0.005
# gini                                          0.000
# hospitalStaffedBedsRate                       0.000
# density                                       0.000
# publicTransRate                               0.000
# deathRate                                     0.000
# householdsWith65Rate                          0.000
# householdIncomeMedian                         0.000
#
#                               AverageDailyTemperature.data   gini  \
# Arithmetic Mean                                      0.000  0.000
# AverageDailyTemperature.data                         0.000  0.000
# gini                                                 0.000  0.000
# hospitalStaffedBedsRate                              0.051  0.000
# density                                              0.118  0.000
# publicTransRate                                      0.172  0.000
# deathRate                                            0.829  0.003
# householdsWith65Rate                                 0.000  0.000
# householdIncomeMedian                                0.005  0.000
#
#                               hospitalStaffedBedsRate  publicTransRate  \
# Arithmetic Mean                                 0.000            0.009
# AverageDailyTemperature.data                    0.051            0.172
# gini                                            0.000            0.000
# hospitalStaffedBedsRate                         0.000            0.297
# density                                         0.047            0.000
# publicTransRate                                 0.297            0.000
# deathRate                                       0.026            0.000
# householdsWith65Rate                            0.655            0.000
# householdIncomeMedian                           0.000            0.000
#
#                               householdsWith65Rate  density
# Arithmetic Mean                              0.516    0.000
# AverageDailyTemperature.data                 0.000    0.118
# gini                                         0.000    0.000
# hospitalStaffedBedsRate                      0.655    0.047
# density                                      0.000    0.000
# publicTransRate                              0.000    0.000
# deathRate                                    0.000    0.003
# householdsWith65Rate                         0.000    0.000
# householdIncomeMedian                        0.000    0.000

# %% [markdown]
# PM2.5

# %%
cols = ['dates','deathRate','Arithmetic Mean','householdIncomeMedian','AverageDailyTemperature.data','gini','hospitalStaffedBedsRate','publicTransRate','householdsWith65Rate','density']
pm25Corr,pVals=covidPollutantFipsCorr(ratesDF, 'pm25', cols)


rows = ['deathRate','publicTransRate','density']
pm25Corr
# Out:
#                               deathRate  Arithmetic Mean  \
# deathRate                          1.00             0.42
# Arithmetic Mean                    0.42             1.00
# householdIncomeMedian              0.13             0.06
# AverageDailyTemperature.data       0.25             0.23
# gini                               0.32             0.10
# hospitalStaffedBedsRate            0.20             0.05
# publicTransRate                    0.59             0.08
# householdsWith65Rate               0.26             0.03
# density                            0.46             0.04
#
#                               householdIncomeMedian  \
# deathRate                                      0.13
# Arithmetic Mean                                0.06
# householdIncomeMedian                          1.00
# AverageDailyTemperature.data                  -0.06
# gini                                          -0.17
# hospitalStaffedBedsRate                       -0.20
# publicTransRate                                0.21
# householdsWith65Rate                           0.23
# density                                        0.18
#
#                               AverageDailyTemperature.data  gini  \
# deathRate                                             0.25  0.32
# Arithmetic Mean                                       0.23  0.10
# householdIncomeMedian                                -0.06 -0.17
# AverageDailyTemperature.data                          1.00  0.30
# gini                                                  0.30  1.00
# hospitalStaffedBedsRate                               0.16  0.40
# publicTransRate                                       0.02  0.31
# householdsWith65Rate                                  0.32  0.29
# density                                               0.15  0.38
#
#                               hospitalStaffedBedsRate  publicTransRate  \
# deathRate                                        0.20             0.59
# Arithmetic Mean                                  0.05             0.08
# householdIncomeMedian                           -0.20             0.21
# AverageDailyTemperature.data                     0.16             0.02
# gini                                             0.40             0.31
# hospitalStaffedBedsRate                          1.00             0.07
# publicTransRate                                  0.07             1.00
# householdsWith65Rate                             0.04             0.30
# density                                          0.18             0.81
#
#                               householdsWith65Rate  density
# deathRate                                     0.26     0.46
# Arithmetic Mean                               0.03     0.04
# householdIncomeMedian                         0.23     0.18
# AverageDailyTemperature.data                  0.32     0.15
# gini                                          0.29     0.38
# hospitalStaffedBedsRate                       0.04     0.18
# publicTransRate                               0.30     0.81
# householdsWith65Rate                          1.00     0.34
# density                                       0.34     1.00

# %%
# p values
# pVals = pm25DF.corr(method=lambda x, y: stats.pearsonr(x, y)[1]) - np.eye(len(pm25DF.corr().columns)) 
pVals
# Out:
#                               deathRate  Arithmetic Mean  \
# Arithmetic Mean                   0.000            0.000
# deathRate                         0.000            0.000
# AverageDailyTemperature.data      0.000            0.000
# gini                              0.000            0.044
# publicTransRate                   0.000            0.125
# householdIncomeMedian             0.011            0.272
# hospitalStaffedBedsRate           0.000            0.410
# density                           0.000            0.515
# householdsWith65Rate              0.000            0.587
#
#                               householdIncomeMedian  \
# Arithmetic Mean                               0.272
# deathRate                                     0.011
# AverageDailyTemperature.data                  0.250
# gini                                          0.001
# publicTransRate                               0.000
# householdIncomeMedian                         0.000
# hospitalStaffedBedsRate                       0.000
# density                                       0.001
# householdsWith65Rate                          0.000
#
#                               AverageDailyTemperature.data   gini  \
# Arithmetic Mean                                      0.000  0.044
# deathRate                                            0.000  0.000
# AverageDailyTemperature.data                         0.000  0.000
# gini                                                 0.000  0.000
# publicTransRate                                      0.635  0.000
# householdIncomeMedian                                0.250  0.001
# hospitalStaffedBedsRate                              0.004  0.000
# density                                              0.004  0.000
# householdsWith65Rate                                 0.000  0.000
#
#                               hospitalStaffedBedsRate  publicTransRate  \
# Arithmetic Mean                                 0.410            0.125
# deathRate                                       0.000            0.000
# AverageDailyTemperature.data                    0.004            0.635
# gini                                            0.000            0.000
# publicTransRate                                 0.190            0.000
# householdIncomeMedian                           0.000            0.000
# hospitalStaffedBedsRate                         0.000            0.190
# density                                         0.001            0.000
# householdsWith65Rate                            0.430            0.000
#
#                               householdsWith65Rate  density
# Arithmetic Mean                              0.587    0.515
# deathRate                                    0.000    0.000
# AverageDailyTemperature.data                 0.000    0.004
# gini                                         0.000    0.000
# publicTransRate                              0.000    0.000
# householdIncomeMedian                        0.000    0.001
# hospitalStaffedBedsRate                      0.430    0.001
# density                                      0.000    0.000
# householdsWith65Rate                         0.000    0.000

# %% [markdown]
# Lead

# %%
cols = ['dates','deathRate','Arithmetic Mean','householdIncomeMedian','AverageDailyTemperature.data','gini','hospitalStaffedBedsRate','publicTransRate','householdsWith65Rate','density']
leadCorr,pVals=covidPollutantFipsCorr(ratesDF, 'lead', cols)


rows = ['deathRate','publicTransRate','density']
leadCorr
# Out:
#                               deathRate  Arithmetic Mean  \
# deathRate                          1.00             0.05
# Arithmetic Mean                    0.05             1.00
# householdIncomeMedian             -0.21            -0.13
# AverageDailyTemperature.data       0.11            -0.01
# gini                               0.12            -0.07
# hospitalStaffedBedsRate            0.06            -0.06
# publicTransRate                    0.19            -0.13
# householdsWith65Rate               0.15            -0.07
# density                            0.13            -0.15
#
#                               householdIncomeMedian  \
# deathRate                                     -0.21
# Arithmetic Mean                               -0.13
# householdIncomeMedian                          1.00
# AverageDailyTemperature.data                  -0.05
# gini                                          -0.18
# hospitalStaffedBedsRate                       -0.35
# publicTransRate                                0.36
# householdsWith65Rate                           0.26
# density                                        0.35
#
#                               AverageDailyTemperature.data  gini  \
# deathRate                                             0.11  0.12
# Arithmetic Mean                                      -0.01 -0.07
# householdIncomeMedian                                -0.05 -0.18
# AverageDailyTemperature.data                          1.00  0.10
# gini                                                  0.10  1.00
# hospitalStaffedBedsRate                               0.13  0.47
# publicTransRate                                      -0.10  0.41
# householdsWith65Rate                                  0.16  0.29
# density                                              -0.04  0.39
#
#                               hospitalStaffedBedsRate  publicTransRate  \
# deathRate                                        0.06             0.19
# Arithmetic Mean                                 -0.06            -0.13
# householdIncomeMedian                           -0.35             0.36
# AverageDailyTemperature.data                     0.13            -0.10
# gini                                             0.47             0.41
# hospitalStaffedBedsRate                          1.00             0.03
# publicTransRate                                  0.03             1.00
# householdsWith65Rate                            -0.08             0.30
# density                                          0.09             0.96
#
#                               householdsWith65Rate  density
# deathRate                                     0.15     0.13
# Arithmetic Mean                              -0.07    -0.15
# householdIncomeMedian                         0.26     0.35
# AverageDailyTemperature.data                  0.16    -0.04
# gini                                          0.29     0.39
# hospitalStaffedBedsRate                      -0.08     0.09
# publicTransRate                               0.30     0.96
# householdsWith65Rate                          1.00     0.22
# density                                       0.22     1.00

# %%
# p values
# pVals = leadDF.corr(method=lambda x, y: stats.pearsonr(x, y)[1]) - np.eye(len(leadDF.corr().columns)) 
pVals
# Out:
#                               deathRate  Arithmetic Mean  \
# Arithmetic Mean                   0.659            0.000
# density                           0.313            0.238
# householdIncomeMedian             0.086            0.272
# publicTransRate                   0.129            0.273
# householdsWith65Rate              0.219            0.548
# gini                              0.335            0.583
# hospitalStaffedBedsRate           0.606            0.612
# deathRate                         0.000            0.659
# AverageDailyTemperature.data      0.380            0.931
#
#                               householdIncomeMedian  \
# Arithmetic Mean                               0.272
# density                                       0.004
# householdIncomeMedian                         0.000
# publicTransRate                               0.002
# householdsWith65Rate                          0.032
# gini                                          0.133
# hospitalStaffedBedsRate                       0.004
# deathRate                                     0.086
# AverageDailyTemperature.data                  0.674
#
#                               AverageDailyTemperature.data   gini  \
# Arithmetic Mean                                      0.931  0.583
# density                                              0.727  0.001
# householdIncomeMedian                                0.674  0.133
# publicTransRate                                      0.435  0.001
# householdsWith65Rate                                 0.194  0.016
# gini                                                 0.392  0.000
# hospitalStaffedBedsRate                              0.285  0.000
# deathRate                                            0.380  0.335
# AverageDailyTemperature.data                         0.000  0.392
#
#                               hospitalStaffedBedsRate  publicTransRate  \
# Arithmetic Mean                                 0.612            0.273
# density                                         0.481            0.000
# householdIncomeMedian                           0.004            0.002
# publicTransRate                                 0.830            0.000
# householdsWith65Rate                            0.511            0.013
# gini                                            0.000            0.001
# hospitalStaffedBedsRate                         0.000            0.830
# deathRate                                       0.606            0.129
# AverageDailyTemperature.data                    0.285            0.435
#
#                               householdsWith65Rate  density
# Arithmetic Mean                              0.548    0.238
# density                                      0.073    0.000
# householdIncomeMedian                        0.032    0.004
# publicTransRate                              0.013    0.000
# householdsWith65Rate                         0.000    0.073
# gini                                         0.016    0.001
# hospitalStaffedBedsRate                      0.511    0.481
# deathRate                                    0.219    0.313
# AverageDailyTemperature.data                 0.194    0.727
